# %%
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
from config import api_key

# %%
DOTA2_High_Earnings_Game_url = "http://api.esportsearnings.com/v0/LookupHighestEarningPlayersByGame?apikeym>&offset=0"

# %%
DOTA2_High_earnings= requests.get(High_Earnings_Game_url).json()

# %%
pprint(DOTA2_High_earnings)
# Out:
# [{'CountryCode': 'dk',
#   'CurrentHandle': 'N0tail',
#   'NameFirst': 'Johan',
#   'NameLast': 'Sundstein',
#   'PlayerId': 3304,
#   'TotalUSDPrize': '6882440.18'},
#  {'CountryCode': 'fi',
#   'CurrentHandle': 'JerAx',
#   'NameFirst': 'Jesse',
#   'NameLast': 'Vainikka',
#   'PlayerId': 3822,
#   'TotalUSDPrize': '6470000.02'},
#  {'CountryCode': 'au',
#   'CurrentHandle': 'ana',
#   'NameFirst': 'Anathan',
#   'NameLast': 'Pham',
#   'PlayerId': 30451,
#   'TotalUSDPrize': '6000411.96'},
#  {'CountryCode': 'fr',
#   'CurrentHandle': 'Ceb',
#   'NameFirst': 'Sébastien',
#   'NameLast': 'Debs',
#   'PlayerId': 2811,
#   'TotalUSDPrize': '5489233.01'},
#  {'CountryCode': 'fi',
#   'CurrentHandle': 'Topson',
#   'NameFirst': 'Topias',
#   'NameLast': 'Taavitsainen',
#   'PlayerId': 18897,
#   'TotalUSDPrize': '5414446.17'},
#  {'CountryCode': 'de',
#   'CurrentHandle': 'KuroKy',
#   'NameFirst': 'Kuro',
#   'NameLast': 'Takhasomi',
#   'PlayerId': 3145,
# ...

# %%
recent_tournaments_url = "http://api.esportsearnings.com/v0/LookupRecentTournaments?apikeym&offset=0"

# %%
recent_tournaments = requests.get(recent_tournaments_url).json()
pprint(recent_tournaments)
# Out:
# [{'EndDate': '2020-04-01',
#   'GameId': 272,
#   'Location': 'Online',
#   'StartDate': '2020-04-01',
#   'Teamplay': 0,
#   'TotalUSDPrize': '110.27',
#   'TournamentId': 40932,
#   'TournamentName': "I'm not a Cow - Cup 3"},
#  {'EndDate': '2020-03-29',
#   'GameId': 504,
#   'Location': 'NA',
#   'StartDate': '2020-03-29',
#   'Teamplay': 1,
#   'TotalUSDPrize': '60.00',
#   'TournamentId': 40935,
#   'TournamentName': '#13 Sun Americas'},
#  {'EndDate': '2020-03-29',
#   'GameId': 272,
#   'Location': 'Online',
#   'StartDate': '2020-03-22',
#   'Teamplay': 0,
#   'TotalUSDPrize': '38.92',
#   'TournamentId': 40908,
#   'TournamentName': 'Battle For The Crown Step 3'},
#  {'EndDate': '2020-03-29',
#   'GameId': 231,
#   'Location': 'Online',
#   'StartDate': '2019-10-17',
#   'Teamplay': 1,
#   'TotalUSDPrize': '211350.00',
#   'TournamentId': 40929,
#   'TournamentName': 'China Dota2 Professional League Season 1'},
#  {'EndDate': '2020-03-29',
#   'GameId': 151,
# ...
